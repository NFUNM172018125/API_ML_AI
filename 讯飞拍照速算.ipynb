# %%
import requests
import datetime
import hashlib
import base64
import hmac
import json

class get_result(object):
    def __init__(self,host):
        # 应用ID（到控制台获取）
        self.APPID = "5e006fe3"
        # 接口APIKey（到控制台拍照速算服务页面获取）
        self.APIKey= "78bfb0eff4e4df95b141c1eda49e5dcc"
        # 接口APISercet（到控制台拍照速算服务页面获取）
        self.Secret = "cd0d879fdb2ffc4ffc0401f4c116c331"
        
        # 以下为POST请求
        self.Host = host
        self.RequestUri = "/v2/itr"
        # 设置url
        # print(host)
        self.url="https://"+host+self.RequestUri
        self.HttpMethod = "POST"
        self.Algorithm = "hmac-sha256"
        self.HttpProto = "HTTP/1.1"

        # 设置当前时间
        curTime_utc = datetime.datetime.utcnow()
        self.Date = self.httpdate(curTime_utc)
        #设置测试图片文件
        self.AudioPath="paizhaosusuan.png"
        self.BusinessArgs={
                "ent": "math-arith",
                "aue": "raw",
            }

    def imgRead(self, path):
        with open(path, 'rb') as fo:
            return fo.read()

    def hashlib_256(self, res):
        m = hashlib.sha256(bytes(res.encode(encoding='utf-8'))).digest()
        result = "SHA-256=" + base64.b64encode(m).decode(encoding='utf-8')
        return result

    def httpdate(self, dt):
        """
        Return a string representation of a date according to RFC 1123
        (HTTP/1.1).

        The supplied date must be in UTC.

        """
        weekday = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"][dt.weekday()]
        month = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep",
                 "Oct", "Nov", "Dec"][dt.month - 1]
        return "%s, %02d %s %04d %02d:%02d:%02d GMT" % (weekday, dt.day, month,
                                                        dt.year, dt.hour, dt.minute, dt.second)

    def generateSignature(self, digest):
        signatureStr = "host: " + self.Host + "\n"
        signatureStr += "date: " + self.Date + "\n"
        signatureStr += self.HttpMethod + " " + self.RequestUri \
                        + " " + self.HttpProto + "\n"
        signatureStr += "digest: " + digest
        signature = hmac.new(bytes(self.Secret.encode(encoding='utf-8')),
                             bytes(signatureStr.encode(encoding='utf-8')),
                             digestmod=hashlib.sha256).digest()
        result = base64.b64encode(signature)
        return result.decode(encoding='utf-8')

    def init_header(self, data):
        digest = self.hashlib_256(data)
        #print(digest)
        sign = self.generateSignature(digest)
        authHeader = 'api_key="%s", algorithm="%s", ' \
                     'headers="host date request-line digest", ' \
                     'signature="%s"' \
                     % (self.APIKey, self.Algorithm, sign)
        #print(authHeader)
        headers = {
            "Content-Type": "application/json",
            "Accept": "application/json",
            "Method": "POST",
            "Host": self.Host,
            "Date": self.Date,
            "Digest": digest,
            "Authorization": authHeader
        }
        return headers

    def get_body(self):
        audioData = self.imgRead((self.AudioPath))
        content = base64.b64encode(audioData).decode(encoding='utf-8')
        postdata = {
            "common": {"app_id": self.APPID},
            "business": self.BusinessArgs,
            "data": {
                "image": content,
            }
        }
        body = json.dumps(postdata)
        #print(body)
        return body

    def call_url(self):
        if self.APPID == '' or self.APIKey == '' or self.Secret == '':
            print('Appid 或APIKey 或APISecret 为空！请打开demo代码，填写相关信息。')
        else:
            code = 0
            body=self.get_body()
            headers=self.init_header(body)
            #print(self.url)
            response = requests.post(self.url, data=body, headers=headers,timeout=8)
            status_code = response.status_code
            #print(response.content)
            if status_code!=200:
                # 鉴权失败
                print("Http请求失败，状态码：" + str(status_code) + "，错误信息：" + response.text)
                print("请根据错误信息检查代码，接口文档：https://www.xfyun.cn/doc/words/photo-calculate-recg/API.html")
            else:
                # 鉴权成功
                respData = json.loads(response.text)
                print(respData)
                # 以下仅用于调试
                code = str(respData["code"])
                if code!='0':
                    print("请前往https://www.xfyun.cn/document/error-code?code=" + code + "查询解决办法")

if __name__ == '__main__':
    ##示例:  host="rest-api.xfyun.cn"域名形式
    host = "rest-api.xfyun.cn"
    #初始化类
    gClass=get_result(host)
    gClass.call_url()
# Out:
# {'code': 0, 'data': {'ITRResult': {'attr_exception': 0, 'category': 'math_phfw_arith', 'multi_line_info': {'imp_line_info': [{'imp_line_rect': {'left_up_point_x': 160, 'left_up_point_y': 32, 'right_down_point_x': 301, 'right_down_point_y': 64}, 'rec_rejection': 0, 'strict_score': 0, 'total_score': 0}, {'imp_line_rect': {'left_up_point_x': 164, 'left_up_point_y': 64, 'right_down_point_x': 305, 'right_down_point_y': 96}, 'rec_rejection': 0, 'strict_score': 0, 'total_score': 1}, {'imp_line_rect': {'left_up_point_x': 163, 'left_up_point_y': 99, 'right_down_point_x': 298, 'right_down_point_y': 126}, 'rec_rejection': 0, 'strict_score': 0, 'total_score': 1}, {'imp_line_rect': {'left_up_point_x': 162, 'left_up_point_y': 128, 'right_down_point_x': 286, 'right_down_point_y': 158}, 'rec_rejection': 0, 'strict_score': 0, 'total_score': 1}, {'imp_line_rect': {'left_up_point_x': 35, 'left_up_point_y': 161, 'right_down_point_x': 143, 'right_down_point_y': 192}, 'rec_rejection': 0, 'strict_score': 0, 'total_score': 1}, {'imp_line_rect': {'left_up_point_x': 172, 'left_up_point_y': 164, 'right_down_point_x': 302, 'right_down_point_y': 192}, 'rec_rejection': 0, 'strict_score': 0, 'total_score': 1}, {'imp_line_rect': {'left_up_point_x': 34, 'left_up_point_y': 192, 'right_down_point_x': 159, 'right_down_point_y': 223}, 'rec_rejection': 0, 'strict_score': 0, 'total_score': 1}, {'imp_line_rect': {'left_up_point_x': 166, 'left_up_point_y': 192, 'right_down_point_x': 305, 'right_down_point_y': 223}, 'rec_rejection': 0, 'strict_score': 0, 'total_score': 1}, {'imp_line_rect': {'left_up_point_x': 34, 'left_up_point_y': 224, 'right_down_point_x': 162, 'right_down_point_y': 255}, 'rec_rejection': 0, 'strict_score': 0, 'total_score': 1}, {'imp_line_rect': {'left_up_point_x': 174, 'left_up_point_y': 225, 'right_down_point_x': 302, 'right_down_point_y': 256}, 'rec_rejection': 0, 'strict_score': 0, 'total_score': 1}, {'imp_line_rect': {'left_up_point_x': 36, 'left_up_point_y': 256, 'right_down_point_x': 173, 'right_down_point_y': 287}, 'rec_rejection': 0, 'strict_score': 0, 'total_score': 1}, {'imp_line_rect': {'left_up_point_x': 175, 'left_up_point_y': 257, 'right_down_point_x': 301, 'right_down_point_y': 287}, 'rec_rejection': 0, 'strict_score': 0, 'total_score': 1}, {'imp_line_rect': {'left_up_point_x': 174, 'left_up_point_y': 287, 'right_down_point_x': 304, 'right_down_point_y': 319}, 'rec_rejection': 0, 'strict_score': 0, 'total_score': 1}, {'imp_line_rect': {'left_up_point_x': 34, 'left_up_point_y': 290, 'right_down_point_x': 152, 'right_down_point_y': 319}, 'rec_rejection': 0, 'strict_score': 0, 'total_score': 0}, {'imp_line_rect': {'left_up_point_x': 34, 'left_up_point_y': 320, 'right_down_point_x': 155, 'right_down_point_y': 351}, 'rec_rejection': 0, 'strict_score': 0, 'total_score': 1}, {'imp_line_rect': {'left_up_point_x': 168, 'left_up_point_y': 320, 'right_down_point_x': 310, 'right_down_point_y': 352}, 'rec_rejection': 0, 'strict_score': 0, 'total_score': 1}, {'imp_line_rect': {'left_up_point_x': 34, 'left_up_point_y': 352, 'right_down_point_x': 168, 'right_down_point_y': 383}, 'rec_rejection': 0, 'strict_score': 0, 'total_score': 0}, {'imp_line_rect': {'left_up_point_x': 174, 'left_up_point_y': 352, 'right_down_point_x': 313, 'right_down_point_y': 384}, 'rec_rejection': 0, 'strict_score': 0, 'total_score': 1}, {'imp_line_rect': {'left_up_point_x': 33, 'left_up_point_y': 383, 'right_down_point_x': 161, 'right_down_point_y': 417}, 'rec_rejection': 0, 'strict_score': 0, 'total_score': 1}, {'imp_line_rect': {'left_up_point_x': 173, 'left_up_point_y': 384, 'right_down_point_x': 309, 'right_down_point_y': 417}, 'rec_rejection': 0, 'strict_score': 0, 'total_score': 1}, {'imp_line_rect': {'left_up_point_x': 177, 'left_up_point_y': 421, 'right_down_point_x': 299, 'right_down_point_y': 449}, 'rec_rejection': 0, 'strict_score': 0, 'total_score': 1}, {'imp_line_rect': {'left_up_point_x': 34, 'left_up_point_y': 422, 'right_down_point_x': 146, 'right_down_poi ...
