# %%
import requests
import http.client
import urllib
import base64
from urllib.parse import quote

with open('./wenzi.jpg', 'rb') as bin_data:
    image_data = bin_data.read()
    image_data_base64 = base64.b64encode(image_data)
    image_data_base64 = quote(image_data_base64)
    conn = http.client.HTTPConnection("openapiai.xueersi.com")
    appkey_string = 'app_key=86fa517ddd65464fb44b180d032bd72d9fa16f46'
    img_string = 'img=' + image_data_base64
    img_type_string = 'img_type=base64'
    payload = appkey_string + '&' + img_string + '&' + img_type_string
    headers = {
        'Content-Type': "application/x-www-form-urlencoded",
        'cache-control': "no-cache",
    }
    conn.request("POST", "/v1/api/img/ocr/general/", payload, headers)
    res = conn.getresponse()
    data = res.read()
    print(data.decode("utf-8"))
    conn.close()
# Out:
# {"code":0,"msg":"请求成功","data":{"recognition":{"ocrId":null,"ocrLinesList":[{"data":[{"alp":null,"height":27,"type":"word","value":"The","width":31,"x":41,"y":1},{"alp":null,"height":27,"type":"word","value":" ","width":31,"x":72,"y":1},{"alp":null,"height":27,"type":"word","value":"terrible","width":31,"x":104,"y":1},{"alp":null,"height":27,"type":"word","value":" ","width":31,"x":136,"y":1},{"alp":null,"height":27,"type":"word","value":"earthquake","width":31,"x":168,"y":1},{"alp":null,"height":27,"type":"word","value":" ","width":31,"x":200,"y":1},{"alp":null,"height":27,"type":"word","value":"and","width":31,"x":232,"y":1},{"alp":null,"height":27,"type":"word","value":" ","width":31,"x":264,"y":1},{"alp":null,"height":27,"type":"word","value":"the","width":31,"x":296,"y":1},{"alp":null,"height":27,"type":"word","value":" ","width":31,"x":328,"y":1},{"alp":null,"height":27,"type":"word","value":"following","width":31,"x":360,"y":1},{"alp":null,"height":27,"type":"word","value":" ","width":31,"x":392,"y":1},{"alp":null,"height":27,"type":"word","value":"tsunami ","width":31,"x":424,"y":1}],"type":"p"},{"data":[{"alp":null,"height":26,"type":"word","value":"have","width":23,"x":41,"y":26},{"alp":null,"height":26,"type":"word","value":" ","width":23,"x":64,"y":26},{"alp":null,"height":26,"type":"word","value":"caused","width":23,"x":88,"y":26},{"alp":null,"height":26,"type":"word","value":" ","width":23,"x":112,"y":26},{"alp":null,"height":26,"type":"word","value":"so","width":23,"x":136,"y":26},{"alp":null,"height":26,"type":"word","value":" ","width":23,"x":160,"y":26},{"alp":null,"height":26,"type":"word","value":"many","width":23,"x":184,"y":26},{"alp":null,"height":26,"type":"word","value":" ","width":23,"x":208,"y":26},{"alp":null,"height":26,"type":"word","value":"people","width":23,"x":232,"y":26},{"alp":null,"height":26,"type":"word","value":"'","width":23,"x":255,"y":26},{"alp":null,"height":26,"type":"word","value":" ","width":23,"x":279,"y":26},{"alp":null,"height":26,"type":"word","value":"injuries","width":23,"x":303,"y":26},{"alp":null,"height":26,"type":"word","value":" ","width":23,"x":327,"y":26},{"alp":null,"height":26,"type":"word","value":"and","width":23,"x":351,"y":26},{"alp":null,"height":26,"type":"word","value":" ","width":23,"x":375,"y":26},{"alp":null,"height":26,"type":"word","value":"deaths","width":23,"x":399,"y":26},{"alp":null,"height":26,"type":"word","value":". ","width":23,"x":423,"y":26}],"type":"p"},{"data":[{"alp":null,"height":25,"type":"word","value":"Besides","width":26,"x":41,"y":51},{"alp":null,"height":25,"type":"word","value":",","width":26,"x":67,"y":51},{"alp":null,"height":25,"type":"word","value":" ","width":26,"x":93,"y":51},{"alp":null,"height":25,"type":"word","value":"many","width":26,"x":120,"y":51},{"alp":null,"height":25,"type":"word","value":" ","width":26,"x":146,"y":51},{"alp":null,"height":25,"type":"word","value":"citizens","width":26,"x":172,"y":51},{"alp":null,"height":25,"type":"word","value":" ","width":26,"x":199,"y":51},{"alp":null,"height":25,"type":"word","value":"become","width":26,"x":225,"y":51},{"alp":null,"height":25,"type":"word","value":" ","width":26,"x":251,"y":51},{"alp":null,"height":25,"type":"word","value":"homeless","width":26,"x":278,"y":51},{"alp":null,"height":25,"type":"word","value":".","width":26,"x":304,"y":51},{"alp":null,"height":25,"type":"word","value":" ","width":26,"x":330,"y":51},{"alp":null,"height":25,"type":"word","value":"We","width":26,"x":357,"y":51},{"alp":null,"height":25,"type":"word","value":" ","width":26,"x":383,"y":51},{"alp":null,"height":25,"type":"word","value":"chinese","width":26,"x":409,"y":51},{"alp":null,"height":25,"type":"word","value":" ","width":26,"x":436,"y":51},{"alp":null,"height":25,"type":"word","value":"feel ","width":26,"x":462,"y":51}],"type":"p"},{"data":[{"alp":null,"height":26,"type":"word","value":"greatly","width":21,"x":41,"y":75},{"alp":null,"height":26,"type":"word","value":" ","width":21," ...
